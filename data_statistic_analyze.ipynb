# %%
import pandas as pd

# %%
columns = ["numbers", "item", "code"]
df = pd.read_csv("./data/data.txt", sep='\t',names=columns, dtype={"numbers": int, "item": str, "code": str})

# %%
df2 = df.groupby(["code"]).size().reset_index(name='counts').sort_values(by='counts', ascending=False)

# %%
df2.loc[df2['counts'] > 150].shape
# Out:
# (647, 2)

# %%
df2.shape
# Out:
# (4099, 2)

# %%
df.groupby(["code"]).sum().sort_values(by="numbers", ascending=False)
# Out:
#         numbers
# code
# 392690  7056032
# 350691  3911190
# 190110  3273666
# 401699  3120902
# 300490  2691330
# 482390  2170063
# 950300  2078924
# 732690  2005104
# 854370  1929567
# 271019  1894980
# 420222  1851887
# 392490  1850820
# 392310  1847749
# 392099  1821494
# 702000  1762635
# 392329  1647206
# 870899  1644683
# 401693  1634678
# 820559  1602050
# 392390  1548944
# 730890  1542535
# 847990  1518200
# 392410  1513876
# 442090  1500515
# 340290  1498924
# 392640  1478875
# 392610  1414624
# 853710  1407611
# 392119  1343865
# 680299  1342355
# ...         ...
# 890610      203
# 930599      199
# 841122      195
# 293293      190
# 844240      188
# 846810      178
# 293212      175
# 910819      171
# 860691      170
# 850240      169
# 293353      167
# 630499      167
# 560391      158
# 080910      135
# 811090      108
# 740313       89
# 293719       88
# 293332       86
# 261710       83
# 930330       76
# 220850       60
# 170310       55
# 081060       54
# ...

# %%
df
# Out:
#         numbers                                               item    code
# 0          3889                                  transparent resin  390730
# 1            99   multi-functional automatic edge grinding machine  846420
# 2           105                            strong bacterium killer  380892
# 3           956                    socket connector for instrument  847330
# 4          4142                                     children's tub  392210
# 5           488                    digital display cutting machine  846490
# 6          2994                              brim striping machine  844819
# 7          1888                                      mc nylon gear  848340
# 8           377                        magnesium sulfate dihydrate  283321
# 9          6357                                    secretary chair  940180
# 10          826                            coloured glaze necklace  711790
# ...
